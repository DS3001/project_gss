# %%
import pandas as pd
pd.set_option('display.max_columns', 500)

url = 'https://github.com/DS3001/project_gss/raw/main/gss_chunk_1.parquet' # Create url to the chunk to be processed
df = pd.read_parquet(url) # Download chunk 1 of data
print(df.shape)
print(df.columns.to_list())
# Out:
# (24130, 6694)
# ...

# %%
df.loc[:, ['year', 'id', 'age', 'sex', 'gunlaw', 'owngun', 'pistol', 'shotgun', 'rifle', 'rowngun', 'hunt']].head()
# Out:
#    year  id   age     sex gunlaw owngun pistol shotgun rifle rowngun hunt
# 0  1972   1  23.0  female  favor    NaN    NaN     NaN   NaN     NaN  NaN
# 1  1972   2  70.0    male  favor    NaN    NaN     NaN   NaN     NaN  NaN
# 2  1972   3  48.0  female  favor    NaN    NaN     NaN   NaN     NaN  NaN
# 3  1972   4  27.0  female  favor    NaN    NaN     NaN   NaN     NaN  NaN
# 4  1972   5  61.0  female  favor    NaN    NaN     NaN   NaN     NaN  NaN

# %%
df.loc[:, ['year', 'id', 'age', 'sex', 'gunlaw', 'owngun', 'pistol', 'shotgun', 'rifle', 'rowngun', 'hunt']].tail(40)
# Out:
#        year   id   age     sex  gunlaw owngun pistol shotgun rifle rowngun  \
# 24090  1989  735  75.0  female   favor     no     no      no    no     NaN
# 24091  1989  736  78.0  female   favor     no     no      no    no     NaN
# 24092  1989  737  58.0  female     NaN    NaN    NaN     NaN   NaN     NaN
# 24093  1989  738  33.0  female  oppose    yes    yes     yes   yes     yes
# 24094  1989  739  25.0  female   favor     no     no      no    no     NaN
# 24095  1989  740  65.0  female     NaN    NaN    NaN     NaN   NaN     NaN
# 24096  1989  741  23.0    male   favor     no     no      no    no     NaN
# 24097  1989  742  23.0    male  oppose    yes    yes      no    no     yes
# 24098  1989  743  46.0    male     NaN    NaN    NaN     NaN   NaN     NaN
# 24099  1989  744  80.0  female   favor     no     no      no    no     NaN
# 24100  1989  745  80.0  female   favor     no     no      no    no     NaN
# ...

# %%
url = 'https://github.com/DS3001/project_gss/raw/main/gss_chunk_2.parquet' # Create url to the chunk to be processed
df = pd.read_parquet(url) # Download chunk 1 of data
df.shape
# Out:
# (24130, 6694)

# %%
df.loc[:, ['year', 'id', 'age', 'sex', 'gunlaw', 'owngun', 'pistol', 'shotgun', 'rifle', 'rowngun', 'hunt']].head(40)
# Out:
#     year   id   age     sex  gunlaw owngun pistol shotgun rifle rowngun  \
# 0   1989  775  62.0    male   favor     no     no      no    no     NaN
# 1   1989  776  32.0  female     NaN    NaN    NaN     NaN   NaN     NaN
# 2   1989  777  80.0  female   favor    yes    yes      no    no     yes
# 3   1989  778  19.0    male  oppose     no     no      no    no     NaN
# 4   1989  779  67.0  female  oppose     no     no      no    no     NaN
# 5   1989  780  39.0  female   favor     no     no      no    no     NaN
# 6   1989  781  25.0    male     NaN    NaN    NaN     NaN   NaN     NaN
# 7   1989  782  71.0    male     NaN    NaN    NaN     NaN   NaN     NaN
# 8   1989  783  59.0    male     NaN    NaN    NaN     NaN   NaN     NaN
# 9   1989  784  82.0  female   favor     no     no      no    no     NaN
# 10  1989  785  56.0    male  oppose    yes    yes     yes   yes     NaN
# 11  1989  786  48.0  female  oppose    yes     no      no   yes     yes
# ...

# %%
df.loc[:, ['year', 'id', 'age', 'sex', 'gunlaw', 'owngun', 'pistol', 'shotgun', 'rifle', 'rowngun', 'hunt']].tail(40)
# Out:
#        year    id   age     sex  gunlaw owngun pistol shotgun rifle rowngun  \
# 24090  2006  1711  60.0  female     NaN    NaN    NaN     NaN   NaN     NaN
# 24091  2006  1712  58.0  female     NaN    NaN    NaN     NaN   NaN     NaN
# 24092  2006  1713  41.0  female     NaN    NaN    NaN     NaN   NaN     NaN
# 24093  2006  1714  29.0    male     NaN    NaN    NaN     NaN   NaN     NaN
# 24094  2006  1715  53.0  female  oppose     no     no      no    no     NaN
# 24095  2006  1716  35.0  female     NaN    NaN    NaN     NaN   NaN     NaN
# 24096  2006  1717  66.0  female     NaN    NaN    NaN     NaN   NaN     NaN
# 24097  2006  1718  59.0  female   favor     no     no      no    no     NaN
# 24098  2006  1719  46.0  female     NaN    NaN    NaN     NaN   NaN     NaN
# 24099  2006  1720  30.0  female   favor     no     no      no    no     NaN
# 24100  2006  1721  48.0    male   favor     no     no      no    no     NaN
# ...

# %%
url = 'https://github.com/DS3001/project_gss/raw/main/gss_chunk_3.parquet' # Create url to the chunk to be processed
df = pd.read_parquet(url) # Download chunk 1 of data
df.shape
# Out:
# (24130, 6694)

# %%
print(df.loc[df['year'] == 2022, 'owngun'].value_counts())
print(sum(df.loc[df['year'] == 2022, 'owngun'].isnull()))
# Out:
# owngun
# no                               1511
# yes                               758
# refused_(3)                        44
# don't know                          0
# iap                                 0
# I don't have a job                  0
# dk, na, iap                         0
# no answer                           0
# not imputable_(2147483637)          0
# not imputable_(2147483638)          0
# refused_(2147483639)                0
# skipped on web                      0
# uncodeable                          0
# not available in this release       0
# not available in this year          0
# see codebook                        0
# Name: count, dtype: int64
# 1231

# %%
print(pd.crosstab(df['hunt'].isnull(), df['owngun']))
# Out:
# owngun   yes     no  refused_(3)
# hunt
# False   5594  10644          290
# True       0      8            7

# %%
print(pd.crosstab(df['divorce'].isnull(), df['marital']))
# Out:
# marital  married  widowed  divorced  separated  never married
# divorce
# False      10920     1956         0          1              0
# True          19        6      3989        752           6446

# %%
df.loc[:, ['year', 'id', 'age', 'sex', 'gunlaw', 'owngun', 'pistol', 'shotgun', 'rifle', 'rowngun', 'hunt']].head(40)
# Out:
#     year    id   age     sex  gunlaw owngun pistol shotgun rifle rowngun  \
# 0   2006  1751  48.0    male     NaN    NaN    NaN     NaN   NaN     NaN
# 1   2006  1752  25.0    male     NaN    NaN    NaN     NaN   NaN     NaN
# 2   2006  1753  42.0    male     NaN    NaN    NaN     NaN   NaN     NaN
# 3   2006  1754  24.0    male     NaN    NaN    NaN     NaN   NaN     NaN
# 4   2006  1755  24.0  female   favor     no     no      no    no     NaN
# 5   2006  1756  31.0    male     NaN    NaN    NaN     NaN   NaN     NaN
# 6   2006  1757  46.0  female     NaN    NaN    NaN     NaN   NaN     NaN
# 7   2006  1758  52.0  female   favor    yes     no      no   yes      no
# 8   2006  1759  42.0    male   favor     no     no      no    no     NaN
# 9   2006  1760  50.0  female     NaN    NaN    NaN     NaN   NaN     NaN
# 10  2006  1761  32.0  female     NaN    NaN    NaN     NaN   NaN     NaN
# 11  2006  1762  48.0  female   favor     no     no      no    no     NaN
# ...

# %%
df.loc[:, ['year', 'id', 'age', 'sex', 'gunlaw', 'owngun', 'pistol', 'shotgun', 'rifle', 'rowngun', 'hunt']].tail(40)
# Out:
#        year    id   age     sex  gunlaw owngun pistol shotgun rifle rowngun  \
# 24090  2022  3506  54.0  female   favor     no     no      no    no     NaN
# 24091  2022  3507  53.0    male   favor    yes    yes     yes   yes     yes
# 24092  2022  3508  80.0    male   favor     no     no      no    no     NaN
# 24093  2022  3509  78.0  female   favor     no     no      no    no     NaN
# 24094  2022  3510  86.0  female   favor     no     no      no    no     NaN
# 24095  2022  3511  67.0    male  oppose    yes    yes     yes   yes     yes
# 24096  2022  3512  27.0    male   favor     no     no      no    no     NaN
# 24097  2022  3513  51.0    male  oppose    yes    yes     yes   yes     yes
# 24098  2022  3514  77.0    male  oppose    yes     no     yes   yes     yes
# 24099  2022  3515  67.0  female  oppose    yes    yes     yes   yes     yes
# 24100  2022  3516  38.0  female   favor    yes    yes     yes   yes     yes
# ...
